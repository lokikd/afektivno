# %% [markdown]
# # Može li računalo prepoznati radnju i glavne likove u film?
# Kad bismo htjeli naučiti robote da razumiju ljudsko ponašanje, morali bismo im puštati da gledaju filmove. Film je medij koji je najbliži stvarnosti. Najjednostavnije, filmovi prikazuju oponašanje osnovnog ljudskog ponašanja. U svojoj dubini, filmovi prenose emocionalne reakcije na psihološka iskustva. Ali filmove je nevjerojatno teško stroju protumačiti. Shvaćali mi to ili ne, postoje mnoge konvencije snimanja filmova koje uzimamo zdravo za gotovo (npr. protok vremena između scena, dramatična glazba tijekom razgovora, montaže). Mi ljudi možemo razumjeti kako to utječe na film, ali može li robot?
#
# Projekt otvorenog koda _Moviegoer_ ima za cilj otključati ogromno bogatstvo emocionalnih podataka unutar kinematografije pretvaranjem filmova u strukturirane podatke. Ti se strukturirani podaci zatim mogu koristiti za treniranje emocionalnih AI modela. Film ima potencijal biti najveći svjetski skup podataka o emocionalnom znanju.
#
# Provedena su mnoga istraživanja u području emocionalnog prepoznavanja lica, analize govora itd., a postoji mnoštvo prethodno obučenih modela koji su besplatno dostupni. Ali ništa od toga ne može se primijeniti na film sve dok ne dekodiramo film u strukturirane podatke.

# %% [markdown]
# ## Četiri kategorije razumijevanja
# Slično kao i ljudski gledatelj, stroj mora biti u stanju analizirati četiri kategorije razumijevanja da bi "gledao film":
# - strukturu filma
# - likove
# - zaplet i događaje
# - stilske značajke.
#
# #### Struktura
# Iako ju publika u potpunosti uzima zdravo za gotovo, film se sastoji od samostalnih jedinica koje se nazivaju "scene", koje se obično odvijaju na fiksnoj lokaciji i uključuju jednog ili više likova. Stroj mora biti u stanju prepoznati početke i završetke pojedinih scena.
#
# Kao polazište, _Moviegoer_ identificira scenu dijaloga s dva lika, temeljnu građevnu jedinicu gotovo svakog filma. Iz perspektive teorije informacija, scene dijaloga s dva lika vrlo su bogate. Nema ometanja, samo dva lika govore i pokreću radnju.
#
# #### Radnja
# Film se sastoji od mnogo različitih događaja. Robot mora razumjeti kako emocionalni značaj određenih događaja (npr. ljubavne afere) utječe na ciljeve karaktera.
#
# #### Likovi
# Svaki lik ima jedinstveno lice i glas, koji se mogu pratiti kroz cijeli film. Oni pomažu u predviđanju demografije likova (dob, rasa, spol). Kako bismo razumjeli motivaciju likova, govorni dijalog mora se pripisati pojedinačnim likovima kako bi se utvrdilo što im je važno.
#
# #### Stil
# To su umjetnički odabiri, poput duljine kadra ili sheme boja, koji se koriste za izazivanje specifičnih emocija kod publike. Glazba je najistaknutiji primjer — iako razumijemo da ta glazba zapravo ne postoji unutar scene, montirana je na scenu kako bi se publika osjećala tužno, uzbuđeno, napeto...
#
# Ova empirijska pravila razvila su se iz više od jednog stoljeća vrijednog napretka u snimanju filmova. U isto vrijeme, neki redatelji će svjesno zanemariti ova pravila kao umjetnički izbor, a gledatelj mora biti spreman prihvatiti te scenarije. No, ako nam recimo pravilo stila pomaže u tumačenju emocija u 99% filmova, u svim žanrovima, to će uvelike pomoći u tumačenju filmova.

# %% [markdown]
# ## Serijalizacija podataka
# Opisan je tijek rada od početka do kraja stvaranja _dataframeova_ iz izvorne filmske datoteke. U biti, tu se "gleda" film. Podatkovni okviri spremaju se kao _pickle_ datoteke za kasniju upotrebu.

# %% [markdown]
# #### 1.  Izdvajaju se pojedinačni kadrovi iz filma - stvara se jedan _jpg_ frame po sekundi filma.

# %%
import cv2
import os

"""
extracts .jpg frames from a movie file and populates into /frame_per_second/ directory
extracts one .jpg per second of film
to use, place movie file in /input_videos/ and change title and optional scale_percent
"""

# create frames from video file
title = 'margaux'
scale_percent = 100     # no image scaling
# scale_percent = 44.44     # optional image scaling, 1080p to 480p

'''change above parameters'''

cap = cv2.VideoCapture('../input_videos/' + title + '.mkv')
# cap = cv2.VideoCapture('input_videos/' + title + '.mp4')
output_directory = os.path.join('../frame_per_second/', title)
#os.mkdir(output_directory)

if not cap.isOpened():
    print("Error opening video stream or file")

frame_rate = cap.get(5)              # frame rate
print('Video frame rate:', frame_rate)  # most movie files will have a frame_rate of 23.976 frames per second


# because of the 23.976 fps frame_rate, we can't just capture every 24 frames
count = 1   # starts at 1, because first image isn't saved until 25th frame (timestamp of 1.001 seconds)
while cap.isOpened():
    ret, frame = cap.read()

    if not ret:
        break
    if cap.get(0) / 1000 >= count:     # first frame after 1 second, 2 seconds, etc.
        filename = output_directory + '/' + title + '_frame_%d.jpg' % count

        # optional image scaling
        width = int(frame.shape[1] * scale_percent / 100)
        height = int(frame.shape[0] * scale_percent / 100)
        dimensions = (width, height)
        frame = cv2.resize(frame, dimensions)

        print(cap.get(0), cap.get(1), count)
        cv2.imwrite(filename, frame)
        count += 1

cap.release()
print('Extracted', count - 1, 'frames')
# Out:
# Video frame rate: 23.976
# 1001.0000000000001 25.0 1
# 2002.0000000000002 49.0 2
# 3003.0 73.0 3
# 4004.0000000000005 97.0 4
# 5005.0 121.0 5
# 6006.0 145.0 6
# 7007.000000000001 169.0 7
# 8008.000000000001 193.0 8
# 9009.0 217.0 9
# 10010.0 241.0 10
# 11011.000000000002 265.0 11
# 12012.0 289.0 12
# 13013.0 313.0 13
# 14014.000000000002 337.0 14
# 15015.0 361.0 15
# 16016.000000000002 385.0 16
# 17017.0 409.0 17
# 18018.0 433.0 18
# 19019.000000000004 457.0 19
# 20020.0 481.0 20
# 21021.0 505.0 21
# 22022.000000000004 529.0 22
# 23023.0 553.0 23
# 24024.0 577.0 24
# 25025.000000000004 601.0 25
# 26026.0 625.0 26
# 27027.0 649.0 27
# 28028.000000000004 673.0 28
# 29029.0 697.0 29
# 30030.0 721.0 30
# 31031.000000000004 745.0 31
# 32032.000000000004 769.0 32
# 33033.0 793.0 33
# 34034.0 817.0 34
# 35035.00000000001 841.0 35
# 36036.0 865.0 36
# 37037.0 889.0 37
# 38038.00000000001 913.0 38
# 39039.0 937.0 39
# 40040.0 961.0 40
# 41041.00000000001 985.0 41
# 42000.0 1008.0 42
# 43001.0 1032.0 43
# 44002.0 1056.0 44
# 45003.0 1080.0 45
# 46004.0 1104.0 46
# 47005.0 1128.0 47
# 48006.0 1152.0 48
# 49007.0 1176.0 49
# 6223015.0 149204.0 6223
# 6224016.000000001 149228.0 6224
# 6225017.0 149252.0 6225
# 6226018.0 149276.0 6226
# 6227019.0 149300.0 6227
# 6228020.0 149324.0 6228
# 6229021.0 149348.0 6229
# 6230022.0 149372.0 6230
# 6231023.0 149396.0 6231
# 6232024.0 149420.0 6232
# 6233025.000000001 149444.0 6233
# 6234026.0 149468.0 6234
# 6235027.0 149492.0 6235
# 6236028.0 149516.0 6236
# 6237029.0 149540.0 6237
# 6238030.0 149564.0 6238
# 6239031.0 149588.0 6239
# 6240032.0 149612.0 6240
# 6241033.0 149636.0 6241
# 6242034.000000001 149660.0 6242
# 6243035.0 149684.0 6243
# 6244036.0 149708.0 6244
# 6245037.0 149732.0 6245
# 6246038.0 149756.0 6246
# Extracted 6246 frames

# %% [markdown]
# #### 2. Stvaranje osnovnih dataframeova

# %%
import sys
import os
sys.path.append('../subtitle_features')
from subtitle_dataframes_io import *
from subtitle_auxiliary_io import *
sys.path.append('../vision_features')
from vision_dataframes_io import *
# sys.path.append('../audio_features')
# from audio_dataframes_io import *
sys.path.append('../unifying_features')
from time_reference_io import *
nlp = spacy.load('en_core_web_sm')

"""
creates base dataframes from image frames and subtitle file, and exports to pickle files
to use, place subtitle file in /subtitles/ and change film and frame_choice
"""

film = 'margaux'
frame_choice = range(1, 6247)   # (1, number of frame files plus one)

'''change above parameters'''

serialized_object_directory = '../serialized_objects/'
film_directory = os.path.join(serialized_object_directory, film)
#os.mkdir(film_directory)

# vision dataframes
face_df = generate_face_df(film, frame_choice)
face_df.to_pickle(os.path.join(film_directory, 'face_df_pre_cluster.pkl'))

vision_df = generate_vision_df(film, frame_choice)
vision_df.to_pickle(os.path.join(film_directory, 'vision_df_pre_cluster.pkl'))


# subtitle dataframes
subs_directory = '../subtitles/'
subs = pysrt.open(os.path.join(subs_directory, film + '.srt'))
srt_df = generate_srt_df(subs)
subtitle_df = generate_base_subtitle_df(subs)
subtitle_df = generate_subtitle_features(subtitle_df)
subtitle_df['cleaned_text'] = subtitle_df['concat_sep_text'].map(clean_line)
sentences = partition_sentences(remove_blanks(subtitle_df['cleaned_text'].tolist()), nlp)
subtitle_indices = tie_sentence_subtitle_indices(sentences, subtitle_df)
sentence_df = pd.DataFrame(list(zip(sentences, subtitle_indices)), columns=['sentence', 'subtitle_indices'])
sentence_df = generate_sentence_features(sentence_df, nlp)
subtitle_df = add_paren_offscreen_speaker(subtitle_df, sentence_df, nlp)

srt_df.to_pickle(os.path.join(film_directory, 'srt_df.pkl'))
subtitle_df.to_pickle(os.path.join(film_directory, 'subtitle_df.pkl'))
sentence_df.to_pickle(os.path.join(film_directory, 'sentence_df_pre_cluster.pkl'))

# %% [markdown]
# #### 3. Korištenje VGG16 modela za stvaranje niza značajki (features) iz svakog okvira u svrhu identifikacije "snimki", u biti klastera sličnih okvira; ovo se izvodi u Docker spremniku za GPU obradu

# %%
import os
import sys
sys.path.append('../venv/lib/python3.6/site-packages')
import numpy as np
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input

"""
uses VGG16 image recognition model to vectorize image files and exports to a single numpy file
does not work on animated movies
to be run in Docker container to take advantage of GPU, using "tensorflow:latest-gpu" Docker image
to use, change film and frame_choice
"""

film = 'margaux'
frame_choice = range(1, 6247)   # (1, number of frame files plus one)

'''change above parameters'''

serialized_object_directory = '../serialized_objects/'
film_directory = os.path.join(serialized_object_directory, film)

image_directory = '../frame_per_second/'
print(os.path.join(image_directory, film))

model = VGG16(weights='imagenet', include_top=False)

vgg16_feature_list = []

for x in frame_choice:
    img_path = os.path.join(image_directory, film) + '/' + film + '_frame_' + str(x) + '.jpg'
    print(img_path)
    img = image.load_img(img_path, target_size=(256, 256))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)

    vgg16_feature = model.predict(img_data)
    vgg16_feature_np = np.array(vgg16_feature)
    vgg16_feature_list.append(vgg16_feature_np.flatten())

    x += 1

vgg16_feature_list_np = np.array(vgg16_feature_list)

print(vgg16_feature_list_np.shape)

np.save(os.path.join(film_directory, 'vgg16_features.npy'), vgg16_feature_list_np)
# Out:
# ../frame_per_second/margaux
# ../frame_per_second/margaux/margaux_frame_1.jpg
# 1/1 [==============================] - 4s 4s/step
# ../frame_per_second/margaux/margaux_frame_2.jpg
# 1/1 [==============================] - 0s 19ms/step
# ../frame_per_second/margaux/margaux_frame_3.jpg
# 1/1 [==============================] - 0s 17ms/step
# ../frame_per_second/margaux/margaux_frame_4.jpg
# 1/1 [==============================] - 0s 9ms/step
# ../frame_per_second/margaux/margaux_frame_5.jpg
# 1/1 [==============================] - 0s 17ms/step
# ../frame_per_second/margaux/margaux_frame_6.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_7.jpg
# 1/1 [==============================] - 0s 22ms/step
# ../frame_per_second/margaux/margaux_frame_8.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_9.jpg
# 1/1 [==============================] - 0s 19ms/step
# ../frame_per_second/margaux/margaux_frame_10.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_11.jpg
# 1/1 [==============================] - 0s 18ms/step
# ../frame_per_second/margaux/margaux_frame_12.jpg
# 1/1 [==============================] - 0s 18ms/step
# ../frame_per_second/margaux/margaux_frame_13.jpg
# 1/1 [==============================] - 0s 11ms/step
# ../frame_per_second/margaux/margaux_frame_14.jpg
# 1/1 [==============================] - 0s 20ms/step
# ../frame_per_second/margaux/margaux_frame_15.jpg
# 1/1 [==============================] - 0s 18ms/step
# ../frame_per_second/margaux/margaux_frame_16.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_17.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_18.jpg
# 1/1 [==============================] - 0s 29ms/step
# ../frame_per_second/margaux/margaux_frame_19.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_20.jpg
# 1/1 [==============================] - 0s 11ms/step
# ../frame_per_second/margaux/margaux_frame_21.jpg
# 1/1 [==============================] - 0s 26ms/step
# ../frame_per_second/margaux/margaux_frame_22.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_23.jpg
# 1/1 [==============================] - 0s 11ms/step
# ../frame_per_second/margaux/margaux_frame_24.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_25.jpg
# 1/1 [==============================] - 0s 21ms/step
# ../frame_per_second/margaux/margaux_frame_26.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_27.jpg
# 1/1 [==============================] - 0s 8ms/step
# ../frame_per_second/margaux/margaux_frame_28.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_29.jpg
# 1/1 [==============================] - 0s 17ms/step
# ../frame_per_second/margaux/margaux_frame_30.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_31.jpg
# 1/1 [==============================] - 0s 10ms/step
# ../frame_per_second/margaux/margaux_frame_32.jpg
# 1/1 [==============================] - 0s 20ms/step
# ../frame_per_second/margaux/margaux_frame_33.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_34.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_35.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_36.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_37.jpg
# 1/1 [==============================] - 0s 0s/step
# ../frame_per_second/margaux/margaux_frame_38.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_39.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_40.jpg
# 1/1 [==============================] - 0s 17ms/step
# ../frame_per_second/margaux/margaux_frame_41.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_42.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_43.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_44.jpg
# 1/1 [==============================] - 0s 5ms/step
# ../frame_per_second/margaux/margaux_frame_45.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_46.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_47.jpg
# 1/1 [==============================] - 0s 3ms/step
# ../frame_per_second/margaux/margaux_frame_48.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_49.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_50.jpg
# 1/1 [==============================] - 0s 19ms/step
# ../frame_per_second/margaux/margaux_frame_51.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_52.jpg
# 1/1 [==============================] - 0s 7ms/step
# ../frame_per_second/margaux/margaux_frame_53.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_54.jpg
# 1/1 [==============================] - 0s 11ms/step
# ../frame_per_second/margaux/margaux_frame_55.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_56.jpg
# 1/1 [==============================] - 0s 12ms/step
# ../frame_per_second/margaux/margaux_frame_57.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_58.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_59.jpg
# 1/1 [==============================] - 0s 12ms/step
# ../frame_per_second/margaux/margaux_frame_60.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_61.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_62.jpg
# 1/1 [==============================] - 0s 6ms/step
# ../frame_per_second/margaux/margaux_frame_63.jpg
# 1/1 [==============================] - 0s 28ms/step
# ../frame_per_second/margaux/margaux_frame_64.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_65.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_66.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_67.jpg
# 1/1 [==============================] - 0s 11ms/step
# ../frame_per_second/margaux/margaux_frame_68.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_69.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_70.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_71.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_72.jpg
# 1/1 [==============================] - 0s 23ms/step
# ../frame_per_second/margaux/margaux_frame_73.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_74.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_75.jpg
# 1/1 [==============================] - 0s 30ms/step
# ../frame_per_second/margaux/margaux_frame_76.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_77.jpg
# 1/1 [==============================] - 0s 17ms/step
# ../frame_per_second/margaux/margaux_frame_78.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_79.jpg
# 1/1 [==============================] - 0s 6ms/step
# ../frame_per_second/margaux/margaux_frame_80.jpg
# 1/1 [==============================] - 0s 25ms/step
# ../frame_per_second/margaux/margaux_frame_81.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_82.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_83.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_84.jpg
# 1/1 [==============================] - 0s 6ms/step
# ../frame_per_second/margaux/margaux_frame_85.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_86.jpg
# 1/1 [==============================] - 0s 0s/step
# ../frame_per_second/margaux/margaux_frame_87.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_88.jpg
# 1/1 [==============================] - 0s 11ms/step
# ../frame_per_second/margaux/margaux_frame_89.jpg
# 1/1 [==============================] - 0s 24ms/step
# ../frame_per_second/margaux/margaux_frame_90.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_91.jpg
# 1/1 [==============================] - 0s 6ms/step
# ../frame_per_second/margaux/margaux_frame_92.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_93.jpg
# 1/1 [==============================] - 0s 11ms/step
# ../frame_per_second/margaux/margaux_frame_94.jpg
# 1/1 [==============================] - 0s 21ms/step
# ../frame_per_second/margaux/margaux_frame_95.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_96.jpg
# 1/1 [==============================] - 0s 6ms/step
# ../frame_per_second/margaux/margaux_frame_97.jpg
# 1/1 [==============================] - 0s 29ms/step
# ../frame_per_second/margaux/margaux_frame_98.jpg
# 1/1 [==============================] - 0s 12ms/step
# ../frame_per_second/margaux/margaux_frame_99.jpg
# 1/1 [==============================] - 0s 19ms/step
# ../frame_per_second/margaux/margaux_frame_100.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_101.jpg
# 1/1 [==============================] - 0s 32ms/step
# ../frame_per_second/margaux/margaux_frame_102.jpg
# 1/1 [==============================] - 0s 7ms/step
# ../frame_per_second/margaux/margaux_frame_103.jpg
# 1/1 [==============================] - 0s 24ms/step
# ../frame_per_second/margaux/margaux_frame_104.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_105.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_106.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_107.jpg
# 1/1 [==============================] - 0s 6ms/step
# ../frame_per_second/margaux/margaux_frame_108.jpg
# 1/1 [==============================] - 0s 29ms/step
# ../frame_per_second/margaux/margaux_frame_109.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_110.jpg
# 1/1 [==============================] - 0s 25ms/step
# ../frame_per_second/margaux/margaux_frame_111.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_112.jpg
# 1/1 [==============================] - 0s 20ms/step
# ../frame_per_second/margaux/margaux_frame_113.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_114.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_115.jpg
# 1/1 [==============================] - 0s 12ms/step
# ../frame_per_second/margaux/margaux_frame_116.jpg
# 1/1 [==============================] - 0s 18ms/step
# ../frame_per_second/margaux/margaux_frame_117.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_118.jpg
# 1/1 [==============================] - 0s 17ms/step
# ../frame_per_second/margaux/margaux_frame_119.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_120.jpg
# 1/1 [==============================] - 0s 5ms/step
# ../frame_per_second/margaux/margaux_frame_121.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_122.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_123.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_124.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_125.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_126.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_127.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_128.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_129.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_130.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_131.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_132.jpg
# 1/1 [==============================] - 0s 30ms/step
# ../frame_per_second/margaux/margaux_frame_133.jpg
# 1/1 [==============================] - 0s 12ms/step
# ../frame_per_second/margaux/margaux_frame_134.jpg
# 1/1 [==============================] - 0s 24ms/step
# ../frame_per_second/margaux/margaux_frame_135.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_136.jpg
# 1/1 [==============================] - 0s 21ms/step
# ../frame_per_second/margaux/margaux_frame_137.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_138.jpg
# 1/1 [==============================] - 0s 18ms/step
# ../frame_per_second/margaux/margaux_frame_139.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_140.jpg
# 1/1 [==============================] - 0s 10ms/step
# ../frame_per_second/margaux/margaux_frame_141.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_142.jpg
# 1/1 [==============================] - 0s 2ms/step
# ../frame_per_second/margaux/margaux_frame_143.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_144.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_145.jpg
# 1/1 [==============================] - 0s 27ms/step
# ../frame_per_second/margaux/margaux_frame_146.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_147.jpg
# 1/1 [==============================] - 0s 19ms/step
# ../frame_per_second/margaux/margaux_frame_148.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_149.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_150.jpg
# 1/1 [==============================] - 0s 21ms/step
# ../frame_per_second/margaux/margaux_frame_151.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_152.jpg
# 1/1 [==============================] - 0s 19ms/step
# ../frame_per_second/margaux/margaux_frame_153.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_154.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_155.jpg
# 1/1 [==============================] - 0s 6ms/step
# ../frame_per_second/margaux/margaux_frame_156.jpg
# 1/1 [==============================] - 0s 17ms/step
# ../frame_per_second/margaux/margaux_frame_157.jpg
# 1/1 [==============================] - 0s 12ms/step
# ../frame_per_second/margaux/margaux_frame_158.jpg
# 1/1 [==============================] - 0s 18ms/step
# ../frame_per_second/margaux/margaux_frame_159.jpg
# 1/1 [==============================] - 0s 1ms/step
# ../frame_per_second/margaux/margaux_frame_160.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_161.jpg
# 1/1 [==============================] - 0s 4ms/step
# ../frame_per_second/margaux/margaux_frame_162.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_163.jpg
# 1/1 [==============================] - 0s 10ms/step
# ../frame_per_second/margaux/margaux_frame_164.jpg
# 1/1 [==============================] - 0s 29ms/step
# ../frame_per_second/margaux/margaux_frame_165.jpg
# 1/1 [==============================] - 0s 12ms/step
# ../frame_per_second/margaux/margaux_frame_166.jpg
# 1/1 [==============================] - 0s 23ms/step
# ../frame_per_second/margaux/margaux_frame_167.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_168.jpg
# 1/1 [==============================] - 0s 28ms/step
# ../frame_per_second/margaux/margaux_frame_169.jpg
# 1/1 [==============================] - 0s 10ms/step
# ../frame_per_second/margaux/margaux_frame_170.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_171.jpg
# 1/1 [==============================] - 0s 8ms/step
# ../frame_per_second/margaux/margaux_frame_172.jpg
# 1/1 [==============================] - 0s 29ms/step
# ../frame_per_second/margaux/margaux_frame_173.jpg
# 1/1 [==============================] - 0s 12ms/step
# ../frame_per_second/margaux/margaux_frame_174.jpg
# 1/1 [==============================] - 0s 20ms/step
# ../frame_per_second/margaux/margaux_frame_175.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_176.jpg
# 1/1 [==============================] - 0s 21ms/step
# ../frame_per_second/margaux/margaux_frame_177.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_178.jpg
# 1/1 [==============================] - 0s 17ms/step
# ../frame_per_second/margaux/margaux_frame_179.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_180.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_181.jpg
# 1/1 [==============================] - 0s 3ms/step
# ../frame_per_second/margaux/margaux_frame_182.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_183.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_184.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_185.jpg
# 1/1 [==============================] - 0s 2ms/step
# ../frame_per_second/margaux/margaux_frame_186.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_187.jpg
# 1/1 [==============================] - 0s 7ms/step
# ../frame_per_second/margaux/margaux_frame_188.jpg
# 1/1 [==============================] - 0s 30ms/step
# ../frame_per_second/margaux/margaux_frame_189.jpg
# 1/1 [==============================] - 0s 11ms/step
# ../frame_per_second/margaux/margaux_frame_190.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_191.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_192.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_193.jpg
# 1/1 [==============================] - 0s 9ms/step
# ../frame_per_second/margaux/margaux_frame_194.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_195.jpg
# 1/1 [==============================] - 0s 24ms/step
# ../frame_per_second/margaux/margaux_frame_196.jpg
# 1/1 [==============================] - 0s 12ms/step
# ../frame_per_second/margaux/margaux_frame_197.jpg
# 1/1 [==============================] - 0s 29ms/step
# ../frame_per_second/margaux/margaux_frame_198.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_199.jpg
# 1/1 [==============================] - 0s 0s/step
# ../frame_per_second/margaux/margaux_frame_200.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_201.jpg
# 1/1 [==============================] - 0s 12ms/step
# ../frame_per_second/margaux/margaux_frame_202.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_203.jpg
# 1/1 [==============================] - 0s 5ms/step
# ../frame_per_second/margaux/margaux_frame_204.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_205.jpg
# 1/1 [==============================] - 0s 12ms/step
# ../frame_per_second/margaux/margaux_frame_206.jpg
# 1/1 [==============================] - 0s 30ms/step
# ../frame_per_second/margaux/margaux_frame_207.jpg
# 1/1 [==============================] - 0s 11ms/step
# ../frame_per_second/margaux/margaux_frame_208.jpg
# 1/1 [==============================] - 0s 29ms/step
# ../frame_per_second/margaux/margaux_frame_209.jpg
# 1/1 [==============================] - 0s 7ms/step
# ../frame_per_second/margaux/margaux_frame_210.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_211.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_212.jpg
# 1/1 [==============================] - 0s 18ms/step
# ../frame_per_second/margaux/margaux_frame_213.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_214.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_215.jpg
# 1/1 [==============================] - 0s 7ms/step
# ../frame_per_second/margaux/margaux_frame_216.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_217.jpg
# 1/1 [==============================] - 0s 25ms/step
# ../frame_per_second/margaux/margaux_frame_218.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_219.jpg
# 1/1 [==============================] - 0s 20ms/step
# ../frame_per_second/margaux/margaux_frame_220.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_221.jpg
# 1/1 [==============================] - 0s 22ms/step
# ../frame_per_second/margaux/margaux_frame_222.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_223.jpg
# 1/1 [==============================] - 0s 23ms/step
# ../frame_per_second/margaux/margaux_frame_224.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_225.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_226.jpg
# 1/1 [==============================] - 0s 0s/step
# ../frame_per_second/margaux/margaux_frame_227.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_228.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_229.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_230.jpg
# 1/1 [==============================] - 0s 20ms/step
# ../frame_per_second/margaux/margaux_frame_231.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_232.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_233.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_234.jpg
# 1/1 [==============================] - 0s 17ms/step
# ../frame_per_second/margaux/margaux_frame_235.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_236.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_237.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_238.jpg
# 1/1 [==============================] - 0s 17ms/step
# ../frame_per_second/margaux/margaux_frame_239.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_240.jpg
# 1/1 [==============================] - 0s 26ms/step
# ../frame_per_second/margaux/margaux_frame_241.jpg
# 1/1 [==============================] - 0s 4ms/step
# ../frame_per_second/margaux/margaux_frame_242.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_243.jpg
# 1/1 [==============================] - 0s 19ms/step
# ../frame_per_second/margaux/margaux_frame_244.jpg
# 1/1 [==============================] - 0s 19ms/step
# ../frame_per_second/margaux/margaux_frame_245.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_246.jpg
# 1/1 [==============================] - 0s 21ms/step
# ../frame_per_second/margaux/margaux_frame_247.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_248.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_249.jpg
# 1/1 [==============================] - 0s 12ms/step
# ../frame_per_second/margaux/margaux_frame_250.jpg
# 1/1 [==============================] - 0s 28ms/step
# ../frame_per_second/margaux/margaux_frame_251.jpg
# 1/1 [==============================] - 0s 10ms/step
# ../frame_per_second/margaux/margaux_frame_252.jpg
# 1/1 [==============================] - 0s 28ms/step
# ../frame_per_second/margaux/margaux_frame_253.jpg
# 1/1 [==============================] - 0s 12ms/step
# ../frame_per_second/margaux/margaux_frame_254.jpg
# 1/1 [==============================] - 0s 22ms/step
# ../frame_per_second/margaux/margaux_frame_255.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_256.jpg
# 1/1 [==============================] - 0s 21ms/step
# ../frame_per_second/margaux/margaux_frame_257.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_258.jpg
# 1/1 [==============================] - 0s 21ms/step
# ../frame_per_second/margaux/margaux_frame_259.jpg
# 1/1 [==============================] - 0s 9ms/step
# ../frame_per_second/margaux/margaux_frame_260.jpg
# 1/1 [==============================] - 0s 29ms/step
# ../frame_per_second/margaux/margaux_frame_261.jpg
# 1/1 [==============================] - 0s 8ms/step
# ../frame_per_second/margaux/margaux_frame_262.jpg
# 1/1 [==============================] - 0s 23ms/step
# ../frame_per_second/margaux/margaux_frame_263.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_264.jpg
# 1/1 [==============================] - 0s 23ms/step
# ../frame_per_second/margaux/margaux_frame_265.jpg
# 1/1 [==============================] - 0s 10ms/step
# ../frame_per_second/margaux/margaux_frame_266.jpg
# 1/1 [==============================] - 0s 28ms/step
# ../frame_per_second/margaux/margaux_frame_267.jpg
# 1/1 [==============================] - 0s 8ms/step
# ../frame_per_second/margaux/margaux_frame_268.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_269.jpg
# 1/1 [==============================] - 0s 10ms/step
# ../frame_per_second/margaux/margaux_frame_270.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_271.jpg
# 1/1 [==============================] - 0s 0s/step
# ../frame_per_second/margaux/margaux_frame_272.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_273.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_274.jpg
# 1/1 [==============================] - 0s 6ms/step
# ../frame_per_second/margaux/margaux_frame_275.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_276.jpg
# 1/1 [==============================] - 0s 7ms/step
# ../frame_per_second/margaux/margaux_frame_277.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_278.jpg
# 1/1 [==============================] - 0s 8ms/step
# ../frame_per_second/margaux/margaux_frame_279.jpg
# 1/1 [==============================] - 0s 29ms/step
# ../frame_per_second/margaux/margaux_frame_280.jpg
# 1/1 [==============================] - 0s 10ms/step
# ../frame_per_second/margaux/margaux_frame_281.jpg
# 1/1 [==============================] - 0s 17ms/step
# ../frame_per_second/margaux/margaux_frame_282.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_283.jpg
# 1/1 [==============================] - 0s 22ms/step
# ../frame_per_second/margaux/margaux_frame_284.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_285.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_286.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_287.jpg
# 1/1 [==============================] - 0s 8ms/step
# ../frame_per_second/margaux/margaux_frame_288.jpg
# 1/1 [==============================] - 0s 20ms/step
# ../frame_per_second/margaux/margaux_frame_289.jpg
# 1/1 [==============================] - 0s 9ms/step
# ../frame_per_second/margaux/margaux_frame_290.jpg
# 1/1 [==============================] - 0s 29ms/step
# ../frame_per_second/margaux/margaux_frame_291.jpg
# 1/1 [==============================] - 0s 12ms/step
# ../frame_per_second/margaux/margaux_frame_292.jpg
# 1/1 [==============================] - 0s 21ms/step
# ../frame_per_second/margaux/margaux_frame_293.jpg
# 1/1 [==============================] - 0s 12ms/step
# ../frame_per_second/margaux/margaux_frame_294.jpg
# 1/1 [==============================] - 0s 27ms/step
# ../frame_per_second/margaux/margaux_frame_295.jpg
# 1/1 [==============================] - 0s 1ms/step
# ../frame_per_second/margaux/margaux_frame_296.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_297.jpg
# 1/1 [==============================] - 0s 0s/step
# ../frame_per_second/margaux/margaux_frame_298.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_299.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_300.jpg
# 1/1 [==============================] - 0s 25ms/step
# ../frame_per_second/margaux/margaux_frame_301.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_302.jpg
# 1/1 [==============================] - 0s 19ms/step
# ../frame_per_second/margaux/margaux_frame_303.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_304.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_305.jpg
# 1/1 [==============================] - 0s 7ms/step
# ../frame_per_second/margaux/margaux_frame_306.jpg
# 1/1 [==============================] - 0s 23ms/step
# ../frame_per_second/margaux/margaux_frame_307.jpg
# 1/1 [==============================] - 0s 12ms/step
# ../frame_per_second/margaux/margaux_frame_308.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_309.jpg
# 1/1 [==============================] - 0s 8ms/step
# ../frame_per_second/margaux/margaux_frame_310.jpg
# 1/1 [==============================] - 0s 27ms/step
# ../frame_per_second/margaux/margaux_frame_311.jpg
# 1/1 [==============================] - 0s 11ms/step
# ../frame_per_second/margaux/margaux_frame_312.jpg
# 1/1 [==============================] - 0s 27ms/step
# ../frame_per_second/margaux/margaux_frame_313.jpg
# 1/1 [==============================] - 0s 12ms/step
# ../frame_per_second/margaux/margaux_frame_314.jpg
# 1/1 [==============================] - 0s 27ms/step
# ../frame_per_second/margaux/margaux_frame_315.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_316.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_317.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_318.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_319.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_320.jpg
# 1/1 [==============================] - 0s 1ms/step
# ../frame_per_second/margaux/margaux_frame_321.jpg
# 1/1 [==============================] - 0s 19ms/step
# ../frame_per_second/margaux/margaux_frame_322.jpg
# 1/1 [==============================] - 0s 6ms/step
# ../frame_per_second/margaux/margaux_frame_323.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_324.jpg
# 1/1 [==============================] - 0s 12ms/step
# ../frame_per_second/margaux/margaux_frame_325.jpg
# 1/1 [==============================] - 0s 24ms/step
# ../frame_per_second/margaux/margaux_frame_326.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_327.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_328.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_329.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_330.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_331.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_332.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_333.jpg
# 1/1 [==============================] - 0s 19ms/step
# ../frame_per_second/margaux/margaux_frame_334.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_335.jpg
# 1/1 [==============================] - 0s 12ms/step
# ../frame_per_second/margaux/margaux_frame_336.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_337.jpg
# 1/1 [==============================] - 0s 5ms/step
# ../frame_per_second/margaux/margaux_frame_338.jpg
# 1/1 [==============================] - 0s 22ms/step
# ../frame_per_second/margaux/margaux_frame_339.jpg
# 1/1 [==============================] - 0s 12ms/step
# ../frame_per_second/margaux/margaux_frame_340.jpg
# 1/1 [==============================] - 0s 26ms/step
# ../frame_per_second/margaux/margaux_frame_341.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_342.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_343.jpg
# 1/1 [==============================] - 0s 0s/step
# ../frame_per_second/margaux/margaux_frame_344.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_345.jpg
# 1/1 [==============================] - 0s 21ms/step
# ../frame_per_second/margaux/margaux_frame_346.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_347.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_348.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_349.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_350.jpg
# 1/1 [==============================] - 0s 6ms/step
# ../frame_per_second/margaux/margaux_frame_351.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_352.jpg
# 1/1 [==============================] - 0s 12ms/step
# ../frame_per_second/margaux/margaux_frame_353.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_354.jpg
# 1/1 [==============================] - 0s 3ms/step
# ../frame_per_second/margaux/margaux_frame_355.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_356.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_357.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_358.jpg
# 1/1 [==============================] - 0s 0s/step
# ../frame_per_second/margaux/margaux_frame_359.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_360.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_361.jpg
# 1/1 [==============================] - 0s 12ms/step
# ../frame_per_second/margaux/margaux_frame_362.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_363.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_364.jpg
# 1/1 [==============================] - 0s 26ms/step
# ../frame_per_second/margaux/margaux_frame_365.jpg
# 1/1 [==============================] - 0s 11ms/step
# ../frame_per_second/margaux/margaux_frame_366.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_367.jpg
# 1/1 [==============================] - 0s 7ms/step
# ../frame_per_second/margaux/margaux_frame_368.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_369.jpg
# 1/1 [==============================] - 0s 4ms/step
# ../frame_per_second/margaux/margaux_frame_370.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_371.jpg
# 1/1 [==============================] - 0s 3ms/step
# ../frame_per_second/margaux/margaux_frame_372.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_373.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_374.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_375.jpg
# 1/1 [==============================] - 0s 7ms/step
# ../frame_per_second/margaux/margaux_frame_376.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_377.jpg
# 1/1 [==============================] - 0s 7ms/step
# ../frame_per_second/margaux/margaux_frame_378.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_379.jpg
# 1/1 [==============================] - 0s 7ms/step
# ../frame_per_second/margaux/margaux_frame_380.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_381.jpg
# 1/1 [==============================] - 0s 18ms/step
# ../frame_per_second/margaux/margaux_frame_382.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_383.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_384.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_385.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_386.jpg
# 1/1 [==============================] - 0s 19ms/step
# ../frame_per_second/margaux/margaux_frame_387.jpg
# 1/1 [==============================] - 0s 9ms/step
# ../frame_per_second/margaux/margaux_frame_388.jpg
# 1/1 [==============================] - 0s 30ms/step
# ../frame_per_second/margaux/margaux_frame_389.jpg
# 1/1 [==============================] - 0s 8ms/step
# ../frame_per_second/margaux/margaux_frame_390.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_391.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_392.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_393.jpg
# 1/1 [==============================] - 0s 18ms/step
# ../frame_per_second/margaux/margaux_frame_394.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_395.jpg
# 1/1 [==============================] - 0s 17ms/step
# ../frame_per_second/margaux/margaux_frame_396.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_397.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_398.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_399.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_400.jpg
# 1/1 [==============================] - 0s 18ms/step
# ../frame_per_second/margaux/margaux_frame_401.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_402.jpg
# 1/1 [==============================] - 0s 19ms/step
# ../frame_per_second/margaux/margaux_frame_403.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_404.jpg
# 1/1 [==============================] - 0s 22ms/step
# ../frame_per_second/margaux/margaux_frame_405.jpg
# 1/1 [==============================] - 0s 11ms/step
# ../frame_per_second/margaux/margaux_frame_406.jpg
# 1/1 [==============================] - 0s 25ms/step
# ../frame_per_second/margaux/margaux_frame_407.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_408.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_409.jpg
# 1/1 [==============================] - 0s 0s/step
# ../frame_per_second/margaux/margaux_frame_410.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_411.jpg
# 1/1 [==============================] - 0s 17ms/step
# ../frame_per_second/margaux/margaux_frame_412.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_413.jpg
# 1/1 [==============================] - 0s 17ms/step
# ../frame_per_second/margaux/margaux_frame_414.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_415.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_416.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_417.jpg
# 1/1 [==============================] - 0s 8ms/step
# ../frame_per_second/margaux/margaux_frame_418.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_419.jpg
# 1/1 [==============================] - 0s 10ms/step
# ../frame_per_second/margaux/margaux_frame_420.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_421.jpg
# 1/1 [==============================] - 0s 22ms/step
# ../frame_per_second/margaux/margaux_frame_422.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_423.jpg
# 1/1 [==============================] - 0s 26ms/step
# ../frame_per_second/margaux/margaux_frame_424.jpg
# 1/1 [==============================] - 0s 18ms/step
# ../frame_per_second/margaux/margaux_frame_425.jpg
# 1/1 [==============================] - 0s 8ms/step
# ../frame_per_second/margaux/margaux_frame_426.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_427.jpg
# 1/1 [==============================] - 0s 18ms/step
# ../frame_per_second/margaux/margaux_frame_428.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_429.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_430.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_431.jpg
# 1/1 [==============================] - 0s 26ms/step
# ../frame_per_second/margaux/margaux_frame_432.jpg
# 1/1 [==============================] - 0s 10ms/step
# ../frame_per_second/margaux/margaux_frame_433.jpg
# 1/1 [==============================] - 0s 29ms/step
# ../frame_per_second/margaux/margaux_frame_434.jpg
# 1/1 [==============================] - 0s 7ms/step
# ../frame_per_second/margaux/margaux_frame_435.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_436.jpg
# 1/1 [==============================] - 0s 22ms/step
# ../frame_per_second/margaux/margaux_frame_437.jpg
# 1/1 [==============================] - 0s 10ms/step
# ../frame_per_second/margaux/margaux_frame_438.jpg
# 1/1 [==============================] - 0s 17ms/step
# ../frame_per_second/margaux/margaux_frame_439.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_440.jpg
# 1/1 [==============================] - 0s 27ms/step
# ../frame_per_second/margaux/margaux_frame_441.jpg
# 1/1 [==============================] - 0s 6ms/step
# ../frame_per_second/margaux/margaux_frame_442.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_443.jpg
# 1/1 [==============================] - 0s 3ms/step
# ../frame_per_second/margaux/margaux_frame_444.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_445.jpg
# 1/1 [==============================] - 0s 24ms/step
# ../frame_per_second/margaux/margaux_frame_446.jpg
# 1/1 [==============================] - 0s 9ms/step
# ../frame_per_second/margaux/margaux_frame_447.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_448.jpg
# 1/1 [==============================] - 0s 0s/step
# ../frame_per_second/margaux/margaux_frame_449.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_450.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_451.jpg
# 1/1 [==============================] - 0s 22ms/step
# ../frame_per_second/margaux/margaux_frame_452.jpg
# 1/1 [==============================] - 0s 10ms/step
# ../frame_per_second/margaux/margaux_frame_453.jpg
# 1/1 [==============================] - 0s 21ms/step
# ../frame_per_second/margaux/margaux_frame_454.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_455.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_456.jpg
# 1/1 [==============================] - 0s 18ms/step
# ../frame_per_second/margaux/margaux_frame_457.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_458.jpg
# 1/1 [==============================] - 0s 17ms/step
# ../frame_per_second/margaux/margaux_frame_459.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_460.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_461.jpg
# 1/1 [==============================] - 0s 1ms/step
# ../frame_per_second/margaux/margaux_frame_462.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_463.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_464.jpg
# 1/1 [==============================] - 0s 4ms/step
# ../frame_per_second/margaux/margaux_frame_465.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_466.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_467.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_468.jpg
# 1/1 [==============================] - 0s 10ms/step
# ../frame_per_second/margaux/margaux_frame_469.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_470.jpg
# 1/1 [==============================] - 0s 7ms/step
# ../frame_per_second/margaux/margaux_frame_471.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_472.jpg
# 1/1 [==============================] - 0s 9ms/step
# ...
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_6092.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_6093.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_6094.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_6095.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_6096.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_6097.jpg
# 1/1 [==============================] - 0s 3ms/step
# ../frame_per_second/margaux/margaux_frame_6098.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_6099.jpg
# 1/1 [==============================] - 0s 25ms/step
# ../frame_per_second/margaux/margaux_frame_6100.jpg
# 1/1 [==============================] - 0s 12ms/step
# ../frame_per_second/margaux/margaux_frame_6101.jpg
# 1/1 [==============================] - 0s 24ms/step
# ../frame_per_second/margaux/margaux_frame_6102.jpg
# 1/1 [==============================] - 0s 12ms/step
# ../frame_per_second/margaux/margaux_frame_6103.jpg
# 1/1 [==============================] - 0s 22ms/step
# ../frame_per_second/margaux/margaux_frame_6104.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_6105.jpg
# 1/1 [==============================] - 0s 25ms/step
# ../frame_per_second/margaux/margaux_frame_6106.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_6107.jpg
# 1/1 [==============================] - 0s 9ms/step
# ../frame_per_second/margaux/margaux_frame_6108.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_6109.jpg
# 1/1 [==============================] - 0s 1ms/step
# ../frame_per_second/margaux/margaux_frame_6110.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_6111.jpg
# 1/1 [==============================] - 0s 11ms/step
# ../frame_per_second/margaux/margaux_frame_6112.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_6113.jpg
# 1/1 [==============================] - 0s 3ms/step
# ../frame_per_second/margaux/margaux_frame_6114.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_6115.jpg
# 1/1 [==============================] - 0s 9ms/step
# ../frame_per_second/margaux/margaux_frame_6116.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_6117.jpg
# 1/1 [==============================] - 0s 5ms/step
# ../frame_per_second/margaux/margaux_frame_6118.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_6119.jpg
# 1/1 [==============================] - 0s 4ms/step
# ../frame_per_second/margaux/margaux_frame_6120.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_6121.jpg
# 1/1 [==============================] - 0s 4ms/step
# ../frame_per_second/margaux/margaux_frame_6122.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_6123.jpg
# 1/1 [==============================] - 0s 2ms/step
# ../frame_per_second/margaux/margaux_frame_6124.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_6125.jpg
# 1/1 [==============================] - 0s 6ms/step
# ../frame_per_second/margaux/margaux_frame_6126.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_6127.jpg
# 1/1 [==============================] - 0s 6ms/step
# ../frame_per_second/margaux/margaux_frame_6128.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_6129.jpg
# 1/1 [==============================] - 0s 10ms/step
# ../frame_per_second/margaux/margaux_frame_6130.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_6131.jpg
# 1/1 [==============================] - 0s 3ms/step
# ../frame_per_second/margaux/margaux_frame_6132.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_6133.jpg
# 1/1 [==============================] - 0s 7ms/step
# ../frame_per_second/margaux/margaux_frame_6134.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_6135.jpg
# 1/1 [==============================] - 0s 2ms/step
# ../frame_per_second/margaux/margaux_frame_6136.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_6137.jpg
# 1/1 [==============================] - 0s 17ms/step
# ../frame_per_second/margaux/margaux_frame_6138.jpg
# 1/1 [==============================] - 0s 2ms/step
# ../frame_per_second/margaux/margaux_frame_6139.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_6140.jpg
# 1/1 [==============================] - 0s 0s/step
# ../frame_per_second/margaux/margaux_frame_6141.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_6142.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_6143.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_6144.jpg
# 1/1 [==============================] - 0s 0s/step
# ../frame_per_second/margaux/margaux_frame_6145.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_6146.jpg
# 1/1 [==============================] - 0s 5ms/step
# ../frame_per_second/margaux/margaux_frame_6147.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_6148.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_6149.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_6150.jpg
# 1/1 [==============================] - 0s 17ms/step
# ../frame_per_second/margaux/margaux_frame_6151.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_6152.jpg
# 1/1 [==============================] - 0s 17ms/step
# ../frame_per_second/margaux/margaux_frame_6153.jpg
# 1/1 [==============================] - 0s 17ms/step
# ../frame_per_second/margaux/margaux_frame_6154.jpg
# 1/1 [==============================] - 0s 24ms/step
# ../frame_per_second/margaux/margaux_frame_6155.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_6156.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_6157.jpg
# 1/1 [==============================] - 0s 26ms/step
# ../frame_per_second/margaux/margaux_frame_6158.jpg
# 1/1 [==============================] - 0s 9ms/step
# ../frame_per_second/margaux/margaux_frame_6159.jpg
# 1/1 [==============================] - 0s 18ms/step
# ../frame_per_second/margaux/margaux_frame_6160.jpg
# 1/1 [==============================] - 0s 8ms/step
# ../frame_per_second/margaux/margaux_frame_6161.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_6162.jpg
# 1/1 [==============================] - 0s 6ms/step
# ../frame_per_second/margaux/margaux_frame_6163.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_6164.jpg
# 1/1 [==============================] - 0s 11ms/step
# ../frame_per_second/margaux/margaux_frame_6165.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_6166.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_6167.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_6168.jpg
# 1/1 [==============================] - 0s 18ms/step
# ../frame_per_second/margaux/margaux_frame_6169.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_6170.jpg
# 1/1 [==============================] - 0s 21ms/step
# ../frame_per_second/margaux/margaux_frame_6171.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_6172.jpg
# 1/1 [==============================] - 0s 24ms/step
# ../frame_per_second/margaux/margaux_frame_6173.jpg
# 1/1 [==============================] - 0s 12ms/step
# ../frame_per_second/margaux/margaux_frame_6174.jpg
# 1/1 [==============================] - 0s 17ms/step
# ../frame_per_second/margaux/margaux_frame_6175.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_6176.jpg
# 1/1 [==============================] - 0s 22ms/step
# ../frame_per_second/margaux/margaux_frame_6177.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_6178.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_6179.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_6180.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_6181.jpg
# 1/1 [==============================] - 0s 3ms/step
# ../frame_per_second/margaux/margaux_frame_6182.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_6183.jpg
# 1/1 [==============================] - 0s 5ms/step
# ../frame_per_second/margaux/margaux_frame_6184.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_6185.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_6186.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_6187.jpg
# 1/1 [==============================] - 0s 2ms/step
# ../frame_per_second/margaux/margaux_frame_6188.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_6189.jpg
# 1/1 [==============================] - 0s 11ms/step
# ../frame_per_second/margaux/margaux_frame_6190.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_6191.jpg
# 1/1 [==============================] - 0s 0s/step
# ../frame_per_second/margaux/margaux_frame_6192.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_6193.jpg
# 1/1 [==============================] - 0s 19ms/step
# ../frame_per_second/margaux/margaux_frame_6194.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_6195.jpg
# 1/1 [==============================] - 0s 25ms/step
# ../frame_per_second/margaux/margaux_frame_6196.jpg
# 1/1 [==============================] - 0s 0s/step
# ../frame_per_second/margaux/margaux_frame_6197.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_6198.jpg
# 1/1 [==============================] - 0s 1ms/step
# ../frame_per_second/margaux/margaux_frame_6199.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_6200.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_6201.jpg
# 1/1 [==============================] - 0s 7ms/step
# ../frame_per_second/margaux/margaux_frame_6202.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_6203.jpg
# 1/1 [==============================] - 0s 24ms/step
# ../frame_per_second/margaux/margaux_frame_6204.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_6205.jpg
# 1/1 [==============================] - 0s 21ms/step
# ../frame_per_second/margaux/margaux_frame_6206.jpg
# 1/1 [==============================] - 0s 11ms/step
# ../frame_per_second/margaux/margaux_frame_6207.jpg
# 1/1 [==============================] - 0s 31ms/step
# ../frame_per_second/margaux/margaux_frame_6208.jpg
# 1/1 [==============================] - 0s 9ms/step
# ../frame_per_second/margaux/margaux_frame_6209.jpg
# 1/1 [==============================] - 0s 30ms/step
# ../frame_per_second/margaux/margaux_frame_6210.jpg
# 1/1 [==============================] - 0s 9ms/step
# ../frame_per_second/margaux/margaux_frame_6211.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_6212.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_6213.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_6214.jpg
# 1/1 [==============================] - 0s 21ms/step
# ../frame_per_second/margaux/margaux_frame_6215.jpg
# 1/1 [==============================] - 0s 13ms/step
# ../frame_per_second/margaux/margaux_frame_6216.jpg
# 1/1 [==============================] - 0s 28ms/step
# ../frame_per_second/margaux/margaux_frame_6217.jpg
# 1/1 [==============================] - 0s 7ms/step
# ../frame_per_second/margaux/margaux_frame_6218.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_6219.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_6220.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_6221.jpg
# 1/1 [==============================] - 0s 4ms/step
# ../frame_per_second/margaux/margaux_frame_6222.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_6223.jpg
# 1/1 [==============================] - 0s 7ms/step
# ../frame_per_second/margaux/margaux_frame_6224.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_6225.jpg
# 1/1 [==============================] - 0s 0s/step
# ../frame_per_second/margaux/margaux_frame_6226.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_6227.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_6228.jpg
# 1/1 [==============================] - 0s 7ms/step
# ../frame_per_second/margaux/margaux_frame_6229.jpg
# 1/1 [==============================] - 0s 28ms/step
# ../frame_per_second/margaux/margaux_frame_6230.jpg
# 1/1 [==============================] - 0s 9ms/step
# ../frame_per_second/margaux/margaux_frame_6231.jpg
# 1/1 [==============================] - 0s 18ms/step
# ../frame_per_second/margaux/margaux_frame_6232.jpg
# 1/1 [==============================] - 0s 9ms/step
# ../frame_per_second/margaux/margaux_frame_6233.jpg
# 1/1 [==============================] - 0s 33ms/step
# ../frame_per_second/margaux/margaux_frame_6234.jpg
# 1/1 [==============================] - 0s 7ms/step
# ../frame_per_second/margaux/margaux_frame_6235.jpg
# 1/1 [==============================] - 0s 14ms/step
# ../frame_per_second/margaux/margaux_frame_6236.jpg
# 1/1 [==============================] - 0s 6ms/step
# ../frame_per_second/margaux/margaux_frame_6237.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_6238.jpg
# 1/1 [==============================] - 0s 27ms/step
# ../frame_per_second/margaux/margaux_frame_6239.jpg
# 1/1 [==============================] - 0s 12ms/step
# ../frame_per_second/margaux/margaux_frame_6240.jpg
# 1/1 [==============================] - 0s 27ms/step
# ../frame_per_second/margaux/margaux_frame_6241.jpg
# 1/1 [==============================] - 0s 9ms/step
# ../frame_per_second/margaux/margaux_frame_6242.jpg
# 1/1 [==============================] - 0s 16ms/step
# ../frame_per_second/margaux/margaux_frame_6243.jpg
# 1/1 [==============================] - 0s 5ms/step
# ../frame_per_second/margaux/margaux_frame_6244.jpg
# 1/1 [==============================] - 0s 15ms/step
# ../frame_per_second/margaux/margaux_frame_6245.jpg
# 1/1 [==============================] - 0s 0s/step
# ../frame_per_second/margaux/margaux_frame_6246.jpg
# 1/1 [==============================] - 0s 15ms/step
# (6246, 32768)

# %% [markdown]
# #### 4. Grupiranje frameova (iz vektorizirane numpay datoteke) i lica (face_df)

# %%
import os
import sys
sys.path.append('../data_serialization')
from serialization_preprocessing_io import *
import pandas as pd
sys.path.append('../subtitle_features')
from subtitle_dataframes_io import *

"""
performs clustering of frames (from saved numpy file of VGG16 vectorizations) and faces (from pickled face_df dataframe)
to use, change film
"""

film = 'margaux'

'''change above parameters'''

serialized_object_directory = '../serialized_objects/'
film_directory = os.path.join(serialized_object_directory, film)
vision_df = pd.read_pickle(os.path.join(film_directory, 'vision_df_pre_cluster.pkl'))
face_df = pd.read_pickle(os.path.join(film_directory, 'face_df_pre_cluster.pkl'))

face_df_clustered = cluster_primary_faces(face_df)
vision_df_clustered = cluster_shots(film, vision_df)

face_df_clustered.to_pickle(os.path.join(film_directory, 'face_df_pre_emotion.pkl'))
vision_df_clustered.to_pickle(os.path.join(film_directory, 'vision_df.pkl'))

sentence_df = pd.read_pickle(os.path.join(film_directory, 'sentence_df_pre_cluster.pkl'))
subtitle_df = pd.read_pickle(os.path.join(film_directory, 'subtitle_df.pkl'))
sentence_df = generate_speakers(sentence_df, subtitle_df, face_df)
sentence_df.to_pickle(os.path.join(film_directory, 'sentence_df.pkl'))

# %% [markdown]
# #### 5. Identificiranje emocija lica kadrova glavnih likova

# %%
import os
import sys
sys.path.append('../venv/lib/python3.6/site-packages')
sys.path.append('../vision_features')
from vision_dataframes_io import *
from deepface import DeepFace
import pandas as pd

"""
performs emotion recognition where primary faces are listed as found in face_df
to use, change film
"""

film = 'margaux'

'''change above parameters'''


def get_primary_char_emotion(film, frame_number):
    frame_folder = os.path.join('../frame_per_second', film)
    img_path = frame_folder + '/' + film + '_frame_' + str(frame_number) + '.jpg'

    obj = DeepFace.analyze(img_path, actions=['emotion'], enforce_detection=False)
    return obj["dominant_emotion"]


serialized_object_directory = '../serialized_objects/'
film_directory = os.path.join(serialized_object_directory, film)

face_df = pd.read_pickle(os.path.join(film_directory, 'face_df_pre_emotion.pkl'))

prim_char_flags = face_df.prim_char_flag.tolist()
frame_list = face_df.index.tolist()

p_emotions_visual = []
x = 0

for flag in prim_char_flags:
    if flag == 1:
        p_emotions_visual.append(get_primary_char_emotion(film, frame_list[x]))
    elif flag == 0:
        p_emotions_visual.append(None)
    x += 1

face_df['p_emotion'] = p_emotions_visual
face_df.to_pickle(os.path.join(film_directory, 'face_df.pkl'))
# Out:
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 147us/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 12ms/step
# ...
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 19ms/step

# %% [markdown]
# ## Likovi
# Film prenosi svoje emocionalne reakcije kroz svoje likove, stoga moramo pratiti likove i njihove emocije kroz film.
#
# #### Pronalaženje scena likova

# %%
import sys
sys.path.append('../unifying_features')
sys.path.append('../data_serialization')
from serialization_preprocessing_io import *
from time_reference_io import *
from scene_identification_io import *
from scene_details_io import *
from character_identification_io import *
from character_details_io import *
nlp = spacy.load('en_core_web_sm')
# Out:
# C:\Users\lkrpan\Anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
film = 'margaux'
srt_df, subtitle_df, sentence_df, vision_df, face_df = read_pickle(film)
scene_dictionaries = generate_scenes(vision_df, face_df, substantial_minimum=1, anchor_search=1)
character_dictionaries = generate_characters(scene_dictionaries)

# %% [markdown]
# Uspjeli smo prepoznati dva glavna lika. Prepoznajemo ih po licima i možemo ih smjestiti u scene koje smo prethodno identificirali.

# %%
scene_dictionaries
# Out:
# {1: {'scene_id': 1,
#   'first_frame': 1716,
#   'last_frame': 1736,
#   'scene_duration': 21,
#   'left_anchor_shot_cluster': 16,
#   'left_anchor_face_cluster': 6.0,
#   'matching_left_face_clusters': [],
#   'right_anchor_shot_cluster': 160,
#   'right_anchor_face_cluster': 8.0,
#   'matching_right_face_clusters': [18.0, 0.0],
#   'cutaway_shot_clusters': []},
#  2: {'scene_id': 2,
#   'first_frame': 3346,
#   'last_frame': 3360,
#   'scene_duration': 15,
#   'left_anchor_shot_cluster': 222,
#   'left_anchor_face_cluster': 18.0,
#   'matching_left_face_clusters': [],
#   'right_anchor_shot_cluster': 78,
#   'right_anchor_face_cluster': 6.0,
#   'matching_right_face_clusters': [7.0],
#   'cutaway_shot_clusters': []},
#  3: {'scene_id': 3,
#   'first_frame': 5250,
#   'last_frame': 5259,
#   'scene_duration': 10,
#   'left_anchor_shot_cluster': 10,
#   'left_anchor_face_cluster': 15.0,
#   'matching_left_face_clusters': [],
#   'right_anchor_shot_cluster': 124,
#   'right_anchor_face_cluster': 9.0,
#   'matching_right_face_clusters': [],
#   'cutaway_shot_clusters': []}}

# %%
character_dictionaries
# Out:
# {1: {'character_id': 1, 'face_clusters': [6.0, 7.0], 'scenes_present': [1, 2]},
#  2: {'character_id': 2,
#   'face_clusters': [0.0, 8.0, 18.0],
#   'scenes_present': [1, 2]}}

# %% [markdown]
# ![Snimka%20zaslona%202022-09-12%20224553.png](attachment:Snimka%20zaslona%202022-09-12%20224553.png)

# %% [markdown]
# ### Demografske informacije
# Možemo koristiti modele prepoznavanja lica kako bismo najbolje prepoznali dob, rasu i spol lika.

# %%
chosen_character_index = 2
chosen_character = character_dictionaries[chosen_character_index]
character_face_clusters = chosen_character['face_clusters']

# %% [markdown]
# Da bismo odabrali odgovarajući frame za prepoznavanja lica, moramo pronaći frame u kojem je lice lika najveće.

# %%
from face_demographics import get_biggest_face_frame, display_character_demographics

biggest_face_frame = get_biggest_face_frame(character_face_clusters, face_df)
print(biggest_face_frame)

biggest_face_frame = biggest_face_frame + 7 #ista slika, ali bolja rezolucija
biggest_face_frame
# Out:
# 1590
# 1597

# %%
obj = display_character_demographics(film, chosen_character_index,biggest_face_frame) 
# print(obj)
# print(obj['age'])
# print(obj['dominant_race'])
# print(obj['gender'])
# Out:
# {'age': 34, 'region': {'x': 582, 'y': 13, 'w': 689, 'h': 689}, 'gender': 'Man', 'race': {'asian': 8.139430731534958, 'indian': 11.579892039299011, 'black': 3.2788585871458054, 'white': 29.662585258483887, 'middle eastern': 25.621813535690308, 'latino hispanic': 21.71742171049118}, 'dominant_race': 'white'}
# 34 years old
# white
# Man

# %% [markdown]
# ![margaux_frame_1597.jpg](attachment:margaux_frame_1597.jpg)

# %% [markdown]
# Možemo vidjeti da je algoritam greškom prepoznao gospodina sa slike umjesto glavnog lika. Pretpostavka je zbog izrezanog dijela kompletnog lica.

# %% [markdown]
# ## Praćenje emocija
# Budući da ćemo na kraju identificirati što uzrokuje emocionalne promjene likova, želimo pratiti njihove emocije kroz cijeli film. Možemo prepoznati njihova lica u cijelom filmu i dodijeliti jednu od sedam emocija. Ovo je šest temeljnih emocija Charlesa Darwina: sretan, tužan, ljut, iznenađen, uplašen i zgađen; dodajemo i neutralno.

# %%
face_df.p_emotion.value_counts()
# Out:
# sad         903
# neutral     506
# angry       277
# happy       229
# fear        218
# surprise     26
# disgust       5
# Name: p_emotion, dtype: int64

# %% [markdown]
# U praksi uglavnom vidimo samo emocije kategorizirane kao tužno, neutralno, prestrašeno, ljuto i sretno. Grupiramo emocije _tužan_ i _ljut_ u jednu kategoriju pod nazivom "uzrujanost". Kad god vidimo lika _uzrujanog_, pretpostavljamo da je u emocionalnoj nevolji. Ove uzrujane emocije možemo iscrtati kroz film. Film se može podijeliti u osam sekvenci (zrnatija verzija strukture od tri čina). Ovo zahtijeva dodatne izračune, ali za sada ćemo ove uznemirene emocije iscrtati kroz osam jednakih trajanja.
#
# Ova radnja otprilike prati tradicionalnu strukturu u tri čina. Većina drame događa se na vrhuncu pri kraju filma, prije nego što kulminira sretnim završetkom.

# %%
plot_character_filmwide_emotion(character_face_clusters, face_df)

# %% [markdown]
# ## Atributi dijaloga
# Pripisivanje dijaloga njihovim govornicima ključni je korak u razumijevanju zapleta i motivacije likova. Međutim, rezultati su malo klimavi. Algoritam pripisuje dijalog utvrđujući tko je na ekranu s otvorenim ustima kada se izgovori rečenica, a to nije uvijek točno.

# %%
display_character_dialogue_context(character_face_clusters, sentence_df, nlp)
# Out:
# ------------------
# Directed Questions
# ------------------
# Hannah, anybody you had any particular first impressions of?
# Is that how you spell it?
# What did you do to them?
# My God, would you please stop doing that?
# Clay, did you lock this?
# Why didn't you say anything?
# What the fuck are you doing, Margaux?
# So, who do you sell all of this to?
# That why you built that firewall on your laptop?
#
# -------------------------------------
# Possible Important Terms, Noun Groups
# -------------------------------------
# ['Hannah', 'Drew', 'babe', 'code', 'Kayla']
#
# -------------------------
# First-Person Declarations
# -------------------------
# I've never seen code like this.
# But, sir, don't I need to go to grad school first?
# I'm sorry I'm late.
# I don't see you.
# Y'all, I'm so stoked you're here.
# Um, I don't know.
# I-It's cool.
# And, I remember Drew being so nice and insisting I was part of the group.
# Nobody goes into a store and says, "Mmm, I'm really craving a marshmallow."
# I think she means these are like 3D-printed shells filled with a nanotech liquid.
# Hey, I'm really glad we're hanging out again.
# I know.
# I mean, I didn't mind.
# I should probably, get some sleep.
# I'm sorry.
# Oh, well, I was just about to eat.
# That's why I'm telling you, I can't drink like that.
# I feel so...
# I'm sorry, but somebody has to say it, okay?
# I don't want to hurt his feelings.
# Actually, I'm gonna go check on Kayla and Devon.
# I miss talking to her, miss hearing about her algorithms, seeing her get excited about code.
#
# -----------------------
# Second-Person Addresses
# -----------------------
# "Hannah, you are a certified genius.
# Is that how you spell it?
# Y'all, I'm so stoked you're here.
# Hannah, anybody you had any particular first impressions of?
# Why didn't you say anything?
# No, we pretty much just called it a night after you went to bed.
# My God, would you please stop doing that?
# Clay, did you lock this?
# What the fuck are you doing, Margaux?
# So, who do you sell all of this to?
# That why you built that firewall on your laptop?
# But you can't.
# What did you do to them?
# Hey, you're okay.

# %%
#pomoćne komande
#!pip3 install pysrt
#!pip3 install pytesseract
#!pip3 uninstall pillow
#!pip3 install Pillow
# Out:
# Requirement already satisfied: pysrt in c:\users\lkrpan\anaconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: chardet in c:\users\lkrpan\anaconda3\lib\site-packages (from pysrt) (4.0.0)
# Requirement already satisfied: pytesseract in c:\users\lkrpan\anaconda3\lib\site-packages (0.3.10)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\lkrpan\anaconda3\lib\site-packages (from pytesseract) (9.0.1)
# Requirement already satisfied: packaging>=21.3 in c:\users\lkrpan\appdata\roaming\python\python39\site-packages (from pytesseract) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\lkrpan\appdata\roaming\python\python39\site-packages (from packaging>=21.3->pytesseract) (3.0.9)
# ^C
# Requirement already satisfied: Pillow in c:\users\lkrpan\anaconda3\lib\site-packages (9.0.1)
